# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
raw = np.load("side_1plate_dark.npy")
n = len(raw)//3

red = raw[:n]
green = raw[n:2*n]
blue = raw[2*n:3*n]

plt.plot(red, c="red")
plt.plot(green, c="green")
plt.plot(blue, c="blue")

# %%
plt.plot(raw)

# %%
raw.shape
# Out:
# (2250,)

# %%
n
# Out:
# 750
